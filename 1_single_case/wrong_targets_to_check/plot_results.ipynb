# %%
import h5py
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import seaborn as sns
import copy
import pickle
import os
import gc

# %%
dir_results_parent = "/orcd/pool/005/vianajr/cluster_ages_1/results/wrong_targets_for_test_single_case/"

dir_results_case = dir_results_parent + f"single_case_1im_remextremes_no_augment_no_blackout_inner_normby_single-image/R_12/"

file_results_all = dir_results_case + "all_models_final_metrics.pkl"

# %%
import pickle

with open(file_results_all, "rb") as f:
    data = pickle.load(f)

print(type(data))
if isinstance(data, dict):
    print("Keys:", data.keys())
elif isinstance(data, list):
    print("Length:", len(data))
    print("First element:", data[0])
else:
    print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pickle
# ----> 3 with open(file_results_all, "rb") as f:
#       4     data = pickle.load(f)
#       6 print(type(data))
#
# File ~/.conda/envs/microlent/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...

# %%
# Loop through and print each key + value
for key, value in data.items():
    print(f"\n=== {key} ===")
    print(value)
# Out:
# === all_tr_final_MSE_nrm ===
# [0.05086455121636391, 0.05223756656050682, 0.05219539254903793, 0.05192225053906441, 0.050590287894010544]
#
# === all_vl_final_MSE_nrm ===
# [0.054617248475551605, 0.054165616631507874, 0.05452004820108414, 0.05406651645898819, 0.05478641018271446]
#
# === all_ts_final_MSE_nrm ===
# [0.054892487823963165, 0.05547129362821579, 0.05561564117670059, 0.05626821145415306, 0.056317441165447235]
#
# === all_tr_final_MdAEs_dnrm ===
# [1.2073027610778808, 1.2057027435302734, 1.219818706512451, 1.2129575300216675, 1.2155493879318238]
#
# === all_vl_final_MdAEs_dnrm ===
# [1.1387428617477418, 1.1484072661399842, 1.1502389025688171, 1.1582290434837341, 1.141326904296875]
#
# === all_ts_final_MdAEs_dnrm ===
# [1.1973918175697327, 1.1658468890190123, 1.1929633498191834, 1.2052153491973876, 1.1979324984550477]
#
# === all_ts_subset_outer_MdAEs_dnrm ===
# [1.1305324697494508, 1.0789976239204406, 1.1036067748069762, 1.1458321046829223, 1.0713723182678223]
#
# ...

# %%
# [1.1973918175697327, 1.1929633498191834, 1.2052153491973876, 1.1979324984550477]

# %%
np.mean([1.1973918175697327, 1.1929633498191834, 1.2052153491973876, 1.1979324984550477])
# Out:
# 1.198375753760338

# %%
np.std([1.1973918175697327, 1.1929633498191834, 1.2052153491973876, 1.1979324984550477])
# Out:
# 0.00439428002799055
